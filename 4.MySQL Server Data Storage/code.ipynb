# %% [markdown]
# # Homework 05 Yifan (Crystal) CAI

# %%
import mysql.connector
import warnings
import requests
import json
import codecs
from bs4 import BeautifulSoup
import pprint
from datetime import datetime
import time

# %% [markdown]
# 1. Go to https://api.github.com and familiarize yourself with the API.

# %% [markdown]
# 2. Go to https://api.github.com/repos/apache/hadoop/contributors . This is the Apache Hadoop Github Repo's contributors’ endpoint. Extract the JSON corresponding to the first 100 contributors from this API. (Hint: the API request is a GET request and the variable name that handles the items per page is "per_page").  Write Java or Python code that does all this.

# %%
### personal identification code
headers = {'Authorization' : 'token ' + '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'}
response = requests.get('https://api.github.com/repos/apache/hadoop/contributors', headers = headers, params={'per_page': 100})
contributors_json = json.loads(response.content)
# len(contributors_json)
pprint.pprint(contributors_json)
# Out:
# [{'avatar_url': 'https://avatars.githubusercontent.com/u/3403122?v=4',
#   'contributions': 816,
#   'events_url': 'https://api.github.com/users/aajisaka/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/aajisaka/followers',
#   'following_url': 'https://api.github.com/users/aajisaka/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/aajisaka/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/aajisaka',
#   'id': 3403122,
#   'login': 'aajisaka',
#   'node_id': 'MDQ6VXNlcjM0MDMxMjI=',
#   'organizations_url': 'https://api.github.com/users/aajisaka/orgs',
#   'received_events_url': 'https://api.github.com/users/aajisaka/received_events',
#   'repos_url': 'https://api.github.com/users/aajisaka/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/aajisaka/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/aajisaka/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/aajisaka'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/384796?v=4',
#   'contributions': 763,
#   'events_url': 'https://api.github.com/users/vinoduec/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/vinoduec/followers',
#   'following_url': 'https://api.github.com/users/vinoduec/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/vinoduec/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/vinoduec',
#   'id': 384796,
#   'login': 'vinoduec',
#   'node_id': 'MDQ6VXNlcjM4NDc5Ng==',
#   'organizations_url': 'https://api.github.com/users/vinoduec/orgs',
#   'received_events_url': 'https://api.github.com/users/vinoduec/received_events',
#   'repos_url': 'https://api.github.com/users/vinoduec/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/vinoduec/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/vinoduec/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/vinoduec'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/907380?v=4',
#   'contributions': 751,
#   'events_url': 'https://api.github.com/users/szetszwo/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/szetszwo/followers',
#   'following_url': 'https://api.github.com/users/szetszwo/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/szetszwo/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/szetszwo',
#   'id': 907380,
#   'login': 'szetszwo',
#   'node_id': 'MDQ6VXNlcjkwNzM4MA==',
#   'organizations_url': 'https://api.github.com/users/szetszwo/orgs',
#   'received_events_url': 'https://api.github.com/users/szetszwo/received_events',
#   'repos_url': 'https://api.github.com/users/szetszwo/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/szetszwo/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/szetszwo/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/szetszwo'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/2480225?v=4',
#   'contributions': 731,
#   'events_url': 'https://api.github.com/users/arp7/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/arp7/followers',
#   'following_url': 'https://api.github.com/users/arp7/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/arp7/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/arp7',
#   'id': 2480225,
#   'login': 'arp7',
#   'node_id': 'MDQ6VXNlcjI0ODAyMjU=',
#   'organizations_url': 'https://api.github.com/users/arp7/orgs',
#   'received_events_url': 'https://api.github.com/users/arp7/received_events',
#   'repos_url': 'https://api.github.com/users/arp7/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/arp7/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/arp7/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/arp7'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/227407?v=4',
#   'contributions': 654,
#   'events_url': 'https://api.github.com/users/cnauroth/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/cnauroth/followers',
#   'following_url': 'https://api.github.com/users/cnauroth/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/cnauroth/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/cnauroth',
#   'id': 227407,
#   'login': 'cnauroth',
#   'node_id': 'MDQ6VXNlcjIyNzQwNw==',
#   'organizations_url': 'https://api.github.com/users/cnauroth/orgs',
#   'received_events_url': 'https://api.github.com/users/cnauroth/received_events',
#   'repos_url': 'https://api.github.com/users/cnauroth/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/cnauroth/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/cnauroth/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/cnauroth'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/1360766?v=4',
#   'contributions': 618,
#   'events_url': 'https://api.github.com/users/jlowe/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/jlowe/followers',
#   'following_url': 'https://api.github.com/users/jlowe/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/jlowe/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/jlowe',
#   'id': 1360766,
#   'login': 'jlowe',
#   'node_id': 'MDQ6VXNlcjEzNjA3NjY=',
#   'organizations_url': 'https://api.github.com/users/jlowe/orgs',
#   'received_events_url': 'https://api.github.com/users/jlowe/received_events',
#   'repos_url': 'https://api.github.com/users/jlowe/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/jlowe/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/jlowe/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/jlowe'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/162090?v=4',
#   'contributions': 614,
#   'events_url': 'https://api.github.com/users/steveloughran/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/steveloughran/followers',
#   'following_url': 'https://api.github.com/users/steveloughran/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/steveloughran/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/steveloughran',
#   'id': 162090,
#   'login': 'steveloughran',
#   'node_id': 'MDQ6VXNlcjE2MjA5MA==',
#   'organizations_url': 'https://api.github.com/users/steveloughran/orgs',
#   'received_events_url': 'https://api.github.com/users/steveloughran/received_events',
#   'repos_url': 'https://api.github.com/users/steveloughran/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/steveloughran/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/steveloughran/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/steveloughran'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/33948?v=4',
#   'contributions': 613,
#   'events_url': 'https://api.github.com/users/umbrant/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/umbrant/followers',
#   'following_url': 'https://api.github.com/users/umbrant/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/umbrant/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/umbrant',
#   'id': 33948,
#   'login': 'umbrant',
#   'node_id': 'MDQ6VXNlcjMzOTQ4',
#   'organizations_url': 'https://api.github.com/users/umbrant/orgs',
#   'received_events_url': 'https://api.github.com/users/umbrant/received_events',
#   'repos_url': 'https://api.github.com/users/umbrant/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/umbrant/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/umbrant/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/umbrant'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/14135?v=4',
#   'contributions': 568,
#   'events_url': 'https://api.github.com/users/toddlipcon/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/toddlipcon/followers',
#   'following_url': 'https://api.github.com/users/toddlipcon/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/toddlipcon/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/toddlipcon',
#   'id': 14135,
#   'login': 'toddlipcon',
#   'node_id': 'MDQ6VXNlcjE0MTM1',
#   'organizations_url': 'https://api.github.com/users/toddlipcon/orgs',
#   'received_events_url': 'https://api.github.com/users/toddlipcon/received_events',
#   'repos_url': 'https://api.github.com/users/toddlipcon/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/toddlipcon/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/toddlipcon/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/toddlipcon'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/2831777?v=4',
#   'contributions': 510,
#   'events_url': 'https://api.github.com/users/anuengineer/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/anuengineer/followers',
#   'following_url': 'https://api.github.com/users/anuengineer/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/anuengineer/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/anuengineer',
#   'id': 2831777,
#   'login': 'anuengineer',
#   'node_id': 'MDQ6VXNlcjI4MzE3Nzc=',
#   'organizations_url': 'https://api.github.com/users/anuengineer/orgs',
#   'received_events_url': 'https://api.github.com/users/anuengineer/received_events',
#   'repos_url': 'https://api.github.com/users/anuengineer/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/anuengineer/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/anuengineer/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/anuengineer'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/148338?v=4',
#   'contributions': 455,
#   'events_url': 'https://api.github.com/users/atm/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/atm/followers',
#   'following_url': 'https://api.github.com/users/atm/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/atm/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/atm',
#   'id': 148338,
#   'login': 'atm',
#   'node_id': 'MDQ6VXNlcjE0ODMzOA==',
#   'organizations_url': 'https://api.github.com/users/atm/orgs',
#   'received_events_url': 'https://api.github.com/users/atm/received_events',
#   'repos_url': 'https://api.github.com/users/atm/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/atm/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/atm/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/atm'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/131502?v=4',
#   'contributions': 441,
#   'events_url': 'https://api.github.com/users/elicollins/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/elicollins/followers',
#   'following_url': 'https://api.github.com/users/elicollins/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/elicollins/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/elicollins',
#   'id': 131502,
#   'login': 'elicollins',
#   'node_id': 'MDQ6VXNlcjEzMTUwMg==',
#   'organizations_url': 'https://api.github.com/users/elicollins/orgs',
#   'received_events_url': 'https://api.github.com/users/elicollins/received_events',
#   'repos_url': 'https://api.github.com/users/elicollins/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/elicollins/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/elicollins/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/elicollins'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/3662775?v=4',
#   'contributions': 422,
#   'events_url': 'https://api.github.com/users/jian-he/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/jian-he/followers',
#   'following_url': 'https://api.github.com/users/jian-he/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/jian-he/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/jian-he',
#   'id': 3662775,
#   'login': 'jian-he',
#   'node_id': 'MDQ6VXNlcjM2NjI3NzU=',
#   'organizations_url': 'https://api.github.com/users/jian-he/orgs',
#   'received_events_url': 'https://api.github.com/users/jian-he/received_events',
#   'repos_url': 'https://api.github.com/users/jian-he/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/jian-he/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/jian-he/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/jian-he'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/359132?v=4',
#   'contributions': 420,
#   'events_url': 'https://api.github.com/users/Jing9/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/Jing9/followers',
#   'following_url': 'https://api.github.com/users/Jing9/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/Jing9/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/Jing9',
#   'id': 359132,
#   'login': 'Jing9',
#   'node_id': 'MDQ6VXNlcjM1OTEzMg==',
#   'organizations_url': 'https://api.github.com/users/Jing9/orgs',
#   'received_events_url': 'https://api.github.com/users/Jing9/received_events',
#   'repos_url': 'https://api.github.com/users/Jing9/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/Jing9/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/Jing9/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/Jing9'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/316888?v=4',
#   'contributions': 392,
#   'events_url': 'https://api.github.com/users/acmurthy/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/acmurthy/followers',
#   'following_url': 'https://api.github.com/users/acmurthy/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/acmurthy/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/acmurthy',
#   'id': 316888,
#   'login': 'acmurthy',
#   'node_id': 'MDQ6VXNlcjMxNjg4OA==',
#   'organizations_url': 'https://api.github.com/users/acmurthy/orgs',
#   'received_events_url': 'https://api.github.com/users/acmurthy/received_events',
#   'repos_url': 'https://api.github.com/users/acmurthy/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/acmurthy/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/acmurthy/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/acmurthy'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/20328673?v=4',
#   'contributions': 376,
#   'events_url': 'https://api.github.com/users/wangdatan/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/wangdatan/followers',
#   'following_url': 'https://api.github.com/users/wangdatan/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/wangdatan/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/wangdatan',
#   'id': 20328673,
#   'login': 'wangdatan',
#   'node_id': 'MDQ6VXNlcjIwMzI4Njcz',
#   'organizations_url': 'https://api.github.com/users/wangdatan/orgs',
#   'received_events_url': 'https://api.github.com/users/wangdatan/received_events',
#   'repos_url': 'https://api.github.com/users/wangdatan/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/wangdatan/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/wangdatan/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/wangdatan'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/7039184?v=4',
#   'contributions': 372,
#   'events_url': 'https://api.github.com/users/xiaoyuyao/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/xiaoyuyao/followers',
#   'following_url': 'https://api.github.com/users/xiaoyuyao/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/xiaoyuyao/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/xiaoyuyao',
#   'id': 7039184,
#   'login': 'xiaoyuyao',
#   'node_id': 'MDQ6VXNlcjcwMzkxODQ=',
#   'organizations_url': 'https://api.github.com/users/xiaoyuyao/orgs',
#   'received_events_url': 'https://api.github.com/users/xiaoyuyao/received_events',
#   'repos_url': 'https://api.github.com/users/xiaoyuyao/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/xiaoyuyao/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/xiaoyuyao/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/xiaoyuyao'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/340000?v=4',
#   'contributions': 363,
#   'events_url': 'https://api.github.com/users/kihwal/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/kihwal/followers',
#   'following_url': 'https://api.github.com/users/kihwal/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/kihwal/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/kihwal',
#   'id': 340000,
#   'login': 'kihwal',
#   'node_id': 'MDQ6VXNlcjM0MDAwMA==',
#   'organizations_url': 'https://api.github.com/users/kihwal/orgs',
#   'received_events_url': 'https://api.github.com/users/kihwal/received_events',
#   'repos_url': 'https://api.github.com/users/kihwal/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/kihwal/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/kihwal/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/kihwal'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/648114?v=4',
#   'contributions': 356,
#   'events_url': 'https://api.github.com/users/kambatla/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/kambatla/followers',
#   'following_url': 'https://api.github.com/users/kambatla/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/kambatla/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/kambatla',
#   'id': 648114,
#   'login': 'kambatla',
#   'node_id': 'MDQ6VXNlcjY0ODExNA==',
#   'organizations_url': 'https://api.github.com/users/kambatla/orgs',
#   'received_events_url': 'https://api.github.com/users/kambatla/received_events',
#   'repos_url': 'https://api.github.com/users/kambatla/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/kambatla/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/kambatla/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/kambatla'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/7998680?v=4',
#   'contributions': 343,
#   'events_url': 'https://api.github.com/users/sunilgovind/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/sunilgovind/followers',
#   'following_url': 'https://api.github.com/users/sunilgovind/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/sunilgovind/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/sunilgovind',
#   'id': 7998680,
#   'login': 'sunilgovind',
#   'node_id': 'MDQ6VXNlcjc5OTg2ODA=',
#   'organizations_url': 'https://api.github.com/users/sunilgovind/orgs',
#   'received_events_url': 'https://api.github.com/users/sunilgovind/received_events',
#   'repos_url': 'https://api.github.com/users/sunilgovind/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/sunilgovind/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/sunilgovind/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/sunilgovind'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/7633626?v=4',
#   'contributions': 297,
#   'events_url': 'https://api.github.com/users/aw-was-here/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/aw-was-here/followers',
#   'following_url': 'https://api.github.com/users/aw-was-here/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/aw-was-here/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/aw-was-here',
#   'id': 7633626,
#   'login': 'aw-was-here',
#   'node_id': 'MDQ6VXNlcjc2MzM2MjY=',
#   'organizations_url': 'https://api.github.com/users/aw-was-here/orgs',
#   'received_events_url': 'https://api.github.com/users/aw-was-here/received_events',
#   'repos_url': 'https://api.github.com/users/aw-was-here/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/aw-was-here/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/aw-was-here/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/aw-was-here'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/954799?v=4',
#   'contributions': 293,
#   'events_url': 'https://api.github.com/users/szilard-nemeth/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/szilard-nemeth/followers',
#   'following_url': 'https://api.github.com/users/szilard-nemeth/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/szilard-nemeth/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/szilard-nemeth',
#   'id': 954799,
#   'login': 'szilard-nemeth',
#   'node_id': 'MDQ6VXNlcjk1NDc5OQ==',
#   'organizations_url': 'https://api.github.com/users/szilard-nemeth/orgs',
#   'received_events_url': 'https://api.github.com/users/szilard-nemeth/received_events',
#   'repos_url': 'https://api.github.com/users/szilard-nemeth/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/szilard-nemeth/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/szilard-nemeth/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/szilard-nemeth'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/25608848?v=4',
#   'contributions': 286,
#   'events_url': 'https://api.github.com/users/ayushtkn/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/ayushtkn/followers',
#   'following_url': 'https://api.github.com/users/ayushtkn/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/ayushtkn/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/ayushtkn',
#   'id': 25608848,
#   'login': 'ayushtkn',
#   'node_id': 'MDQ6VXNlcjI1NjA4ODQ4',
#   'organizations_url': 'https://api.github.com/users/ayushtkn/orgs',
#   'received_events_url': 'https://api.github.com/users/ayushtkn/received_events',
#   'repos_url': 'https://api.github.com/users/ayushtkn/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/ayushtkn/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/ayushtkn/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/ayushtkn'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/3441321?v=4',
#   'contributions': 283,
#   'events_url': 'https://api.github.com/users/revans2/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/revans2/followers',
#   'following_url': 'https://api.github.com/users/revans2/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/revans2/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/revans2',
#   'id': 3441321,
#   'login': 'revans2',
#   'node_id': 'MDQ6VXNlcjM0NDEzMjE=',
#   'organizations_url': 'https://api.github.com/users/revans2/orgs',
#   'received_events_url': 'https://api.github.com/users/revans2/received_events',
#   'repos_url': 'https://api.github.com/users/revans2/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/revans2/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/revans2/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/revans2'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/15498544?v=4',
#   'contributions': 275,
#   'events_url': 'https://api.github.com/users/vinayakumarb/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/vinayakumarb/followers',
#   'following_url': 'https://api.github.com/users/vinayakumarb/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/vinayakumarb/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/vinayakumarb',
#   'id': 15498544,
#   'login': 'vinayakumarb',
#   'node_id': 'MDQ6VXNlcjE1NDk4NTQ0',
#   'organizations_url': 'https://api.github.com/users/vinayakumarb/orgs',
#   'received_events_url': 'https://api.github.com/users/vinayakumarb/received_events',
#   'repos_url': 'https://api.github.com/users/vinayakumarb/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/vinayakumarb/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/vinayakumarb/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/vinayakumarb'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/328366?v=4',
#   'contributions': 258,
#   'events_url': 'https://api.github.com/users/macroadster/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/macroadster/followers',
#   'following_url': 'https://api.github.com/users/macroadster/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/macroadster/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/macroadster',
#   'id': 328366,
#   'login': 'macroadster',
#   'node_id': 'MDQ6VXNlcjMyODM2Ng==',
#   'organizations_url': 'https://api.github.com/users/macroadster/orgs',
#   'received_events_url': 'https://api.github.com/users/macroadster/received_events',
#   'repos_url': 'https://api.github.com/users/macroadster/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/macroadster/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/macroadster/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/macroadster'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/2691807?v=4',
#   'contributions': 250,
#   'events_url': 'https://api.github.com/users/jojochuang/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/jojochuang/followers',
#   'following_url': 'https://api.github.com/users/jojochuang/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/jojochuang/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/jojochuang',
#   'id': 2691807,
#   'login': 'jojochuang',
#   'node_id': 'MDQ6VXNlcjI2OTE4MDc=',
#   'organizations_url': 'https://api.github.com/users/jojochuang/orgs',
#   'received_events_url': 'https://api.github.com/users/jojochuang/received_events',
#   'repos_url': 'https://api.github.com/users/jojochuang/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/jojochuang/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/jojochuang/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/jojochuang'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/888093?v=4',
#   'contributions': 236,
#   'events_url': 'https://api.github.com/users/JunpingDu/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/JunpingDu/followers',
#   'following_url': 'https://api.github.com/users/JunpingDu/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/JunpingDu/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/JunpingDu',
#   'id': 888093,
#   'login': 'JunpingDu',
#   'node_id': 'MDQ6VXNlcjg4ODA5Mw==',
#   'organizations_url': 'https://api.github.com/users/JunpingDu/orgs',
#   'received_events_url': 'https://api.github.com/users/JunpingDu/received_events',
#   'repos_url': 'https://api.github.com/users/JunpingDu/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/JunpingDu/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/JunpingDu/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/JunpingDu'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/85085?v=4',
#   'contributions': 221,
#   'events_url': 'https://api.github.com/users/tomwhite/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/tomwhite/followers',
#   'following_url': 'https://api.github.com/users/tomwhite/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/tomwhite/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/tomwhite',
#   'id': 85085,
#   'login': 'tomwhite',
#   'node_id': 'MDQ6VXNlcjg1MDg1',
#   'organizations_url': 'https://api.github.com/users/tomwhite/orgs',
#   'received_events_url': 'https://api.github.com/users/tomwhite/received_events',
#   'repos_url': 'https://api.github.com/users/tomwhite/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/tomwhite/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/tomwhite/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/tomwhite'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/8586345?v=4',
#   'contributions': 219,
#   'events_url': 'https://api.github.com/users/bharatviswa504/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/bharatviswa504/followers',
#   'following_url': 'https://api.github.com/users/bharatviswa504/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/bharatviswa504/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/bharatviswa504',
#   'id': 8586345,
#   'login': 'bharatviswa504',
#   'node_id': 'MDQ6VXNlcjg1ODYzNDU=',
#   'organizations_url': 'https://api.github.com/users/bharatviswa504/orgs',
#   'received_events_url': 'https://api.github.com/users/bharatviswa504/received_events',
#   'repos_url': 'https://api.github.com/users/bharatviswa504/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/bharatviswa504/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/bharatviswa504/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/bharatviswa504'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/14214570?v=4',
#   'contributions': 212,
#   'events_url': 'https://api.github.com/users/yangwwei/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/yangwwei/followers',
#   'following_url': 'https://api.github.com/users/yangwwei/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/yangwwei/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/yangwwei',
#   'id': 14214570,
#   'login': 'yangwwei',
#   'node_id': 'MDQ6VXNlcjE0MjE0NTcw',
#   'organizations_url': 'https://api.github.com/users/yangwwei/orgs',
#   'received_events_url': 'https://api.github.com/users/yangwwei/received_events',
#   'repos_url': 'https://api.github.com/users/yangwwei/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/yangwwei/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/yangwwei/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/yangwwei'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/170549?v=4',
#   'contributions': 211,
#   'events_url': 'https://api.github.com/users/elek/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/elek/followers',
#   'following_url': 'https://api.github.com/users/elek/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/elek/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/elek',
#   'id': 170549,
#   'login': 'elek',
#   'node_id': 'MDQ6VXNlcjE3MDU0OQ==',
#   'organizations_url': 'https://api.github.com/users/elek/orgs',
#   'received_events_url': 'https://api.github.com/users/elek/received_events',
#   'repos_url': 'https://api.github.com/users/elek/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/elek/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/elek/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/elek'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/15336756?v=4',
#   'contributions': 198,
#   'events_url': 'https://api.github.com/users/rohithsharmaks/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/rohithsharmaks/followers',
#   'following_url': 'https://api.github.com/users/rohithsharmaks/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/rohithsharmaks/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/rohithsharmaks',
#   'id': 15336756,
#   'login': 'rohithsharmaks',
#   'node_id': 'MDQ6VXNlcjE1MzM2NzU2',
#   'organizations_url': 'https://api.github.com/users/rohithsharmaks/orgs',
#   'received_events_url': 'https://api.github.com/users/rohithsharmaks/received_events',
#   'repos_url': 'https://api.github.com/users/rohithsharmaks/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/rohithsharmaks/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/rohithsharmaks/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/rohithsharmaks'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/104111?v=4',
#   'contributions': 190,
#   'events_url': 'https://api.github.com/users/oza/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/oza/followers',
#   'following_url': 'https://api.github.com/users/oza/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/oza/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/oza',
#   'id': 104111,
#   'login': 'oza',
#   'node_id': 'MDQ6VXNlcjEwNDExMQ==',
#   'organizations_url': 'https://api.github.com/users/oza/orgs',
#   'received_events_url': 'https://api.github.com/users/oza/received_events',
#   'repos_url': 'https://api.github.com/users/oza/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/oza/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/oza/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/oza'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/7877836?v=4',
#   'contributions': 188,
#   'events_url': 'https://api.github.com/users/linyiqun/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/linyiqun/followers',
#   'following_url': 'https://api.github.com/users/linyiqun/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/linyiqun/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/linyiqun',
#   'id': 7877836,
#   'login': 'linyiqun',
#   'node_id': 'MDQ6VXNlcjc4Nzc4MzY=',
#   'organizations_url': 'https://api.github.com/users/linyiqun/orgs',
#   'received_events_url': 'https://api.github.com/users/linyiqun/received_events',
#   'repos_url': 'https://api.github.com/users/linyiqun/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/linyiqun/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/linyiqun/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/linyiqun'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/1095624?v=4',
#   'contributions': 185,
#   'events_url': 'https://api.github.com/users/cmccabe/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/cmccabe/followers',
#   'following_url': 'https://api.github.com/users/cmccabe/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/cmccabe/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/cmccabe',
#   'id': 1095624,
#   'login': 'cmccabe',
#   'node_id': 'MDQ6VXNlcjEwOTU2MjQ=',
#   'organizations_url': 'https://api.github.com/users/cmccabe/orgs',
#   'received_events_url': 'https://api.github.com/users/cmccabe/received_events',
#   'repos_url': 'https://api.github.com/users/cmccabe/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/cmccabe/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/cmccabe/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/cmccabe'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/14279024?v=4',
#   'contributions': 180,
#   'events_url': 'https://api.github.com/users/xiao-chen/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/xiao-chen/followers',
#   'following_url': 'https://api.github.com/users/xiao-chen/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/xiao-chen/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/xiao-chen',
#   'id': 14279024,
#   'login': 'xiao-chen',
#   'node_id': 'MDQ6VXNlcjE0Mjc5MDI0',
#   'organizations_url': 'https://api.github.com/users/xiao-chen/orgs',
#   'received_events_url': 'https://api.github.com/users/xiao-chen/received_events',
#   'repos_url': 'https://api.github.com/users/xiao-chen/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/xiao-chen/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/xiao-chen/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/xiao-chen'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/3588587?v=4',
#   'contributions': 179,
#   'events_url': 'https://api.github.com/users/rkanter/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/rkanter/followers',
#   'following_url': 'https://api.github.com/users/rkanter/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/rkanter/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/rkanter',
#   'id': 3588587,
#   'login': 'rkanter',
#   'node_id': 'MDQ6VXNlcjM1ODg1ODc=',
#   'organizations_url': 'https://api.github.com/users/rkanter/orgs',
#   'received_events_url': 'https://api.github.com/users/rkanter/received_events',
#   'repos_url': 'https://api.github.com/users/rkanter/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/rkanter/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/rkanter/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/rkanter'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/159186?v=4',
#   'contributions': 174,
#   'events_url': 'https://api.github.com/users/liuml07/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/liuml07/followers',
#   'following_url': 'https://api.github.com/users/liuml07/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/liuml07/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/liuml07',
#   'id': 159186,
#   'login': 'liuml07',
#   'node_id': 'MDQ6VXNlcjE1OTE4Ng==',
#   'organizations_url': 'https://api.github.com/users/liuml07/orgs',
#   'received_events_url': 'https://api.github.com/users/liuml07/received_events',
#   'repos_url': 'https://api.github.com/users/liuml07/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/liuml07/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/liuml07/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/liuml07'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/31204?v=4',
#   'contributions': 162,
#   'events_url': 'https://api.github.com/users/xslogic/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/xslogic/followers',
#   'following_url': 'https://api.github.com/users/xslogic/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/xslogic/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/xslogic',
#   'id': 31204,
#   'login': 'xslogic',
#   'node_id': 'MDQ6VXNlcjMxMjA0',
#   'organizations_url': 'https://api.github.com/users/xslogic/orgs',
#   'received_events_url': 'https://api.github.com/users/xslogic/received_events',
#   'repos_url': 'https://api.github.com/users/xslogic/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/xslogic/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/xslogic/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/xslogic'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/1719507?v=4',
#   'contributions': 161,
#   'events_url': 'https://api.github.com/users/umamaheswararao/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/umamaheswararao/followers',
#   'following_url': 'https://api.github.com/users/umamaheswararao/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/umamaheswararao/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/umamaheswararao',
#   'id': 1719507,
#   'login': 'umamaheswararao',
#   'node_id': 'MDQ6VXNlcjE3MTk1MDc=',
#   'organizations_url': 'https://api.github.com/users/umamaheswararao/orgs',
#   'received_events_url': 'https://api.github.com/users/umamaheswararao/received_events',
#   'repos_url': 'https://api.github.com/users/umamaheswararao/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/umamaheswararao/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/umamaheswararao/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/umamaheswararao'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/145508?v=4',
#   'contributions': 161,
#   'events_url': 'https://api.github.com/users/cdouglas/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/cdouglas/followers',
#   'following_url': 'https://api.github.com/users/cdouglas/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/cdouglas/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/cdouglas',
#   'id': 145508,
#   'login': 'cdouglas',
#   'node_id': 'MDQ6VXNlcjE0NTUwOA==',
#   'organizations_url': 'https://api.github.com/users/cdouglas/orgs',
#   'received_events_url': 'https://api.github.com/users/cdouglas/received_events',
#   'repos_url': 'https://api.github.com/users/cdouglas/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/cdouglas/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/cdouglas/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/cdouglas'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/35021395?v=4',
#   'contributions': 160,
#   'events_url': 'https://api.github.com/users/zjshen14/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/zjshen14/followers',
#   'following_url': 'https://api.github.com/users/zjshen14/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/zjshen14/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/zjshen14',
#   'id': 35021395,
#   'login': 'zjshen14',
#   'node_id': 'MDQ6VXNlcjM1MDIxMzk1',
#   'organizations_url': 'https://api.github.com/users/zjshen14/orgs',
#   'received_events_url': 'https://api.github.com/users/zjshen14/received_events',
#   'repos_url': 'https://api.github.com/users/zjshen14/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/zjshen14/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/zjshen14/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/zjshen14'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/8871229?v=4',
#   'contributions': 157,
#   'events_url': 'https://api.github.com/users/nandakumar131/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/nandakumar131/followers',
#   'following_url': 'https://api.github.com/users/nandakumar131/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/nandakumar131/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/nandakumar131',
#   'id': 8871229,
#   'login': 'nandakumar131',
#   'node_id': 'MDQ6VXNlcjg4NzEyMjk=',
#   'organizations_url': 'https://api.github.com/users/nandakumar131/orgs',
#   'received_events_url': 'https://api.github.com/users/nandakumar131/received_events',
#   'repos_url': 'https://api.github.com/users/nandakumar131/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/nandakumar131/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/nandakumar131/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/nandakumar131'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/654855?v=4',
#   'contributions': 156,
#   'events_url': 'https://api.github.com/users/sryza/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/sryza/followers',
#   'following_url': 'https://api.github.com/users/sryza/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/sryza/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/sryza',
#   'id': 654855,
#   'login': 'sryza',
#   'node_id': 'MDQ6VXNlcjY1NDg1NQ==',
#   'organizations_url': 'https://api.github.com/users/sryza/orgs',
#   'received_events_url': 'https://api.github.com/users/sryza/received_events',
#   'repos_url': 'https://api.github.com/users/sryza/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/sryza/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/sryza/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/sryza'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/11998604?v=4',
#   'contributions': 154,
#   'events_url': 'https://api.github.com/users/shvachko/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/shvachko/followers',
#   'following_url': 'https://api.github.com/users/shvachko/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/shvachko/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/shvachko',
#   'id': 11998604,
#   'login': 'shvachko',
#   'node_id': 'MDQ6VXNlcjExOTk4NjA0',
#   'organizations_url': 'https://api.github.com/users/shvachko/orgs',
#   'received_events_url': 'https://api.github.com/users/shvachko/received_events',
#   'repos_url': 'https://api.github.com/users/shvachko/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/shvachko/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/shvachko/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/shvachko'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/34790606?v=4',
#   'contributions': 140,
#   'events_url': 'https://api.github.com/users/virajjasani/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/virajjasani/followers',
#   'following_url': 'https://api.github.com/users/virajjasani/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/virajjasani/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/virajjasani',
#   'id': 34790606,
#   'login': 'virajjasani',
#   'node_id': 'MDQ6VXNlcjM0NzkwNjA2',
#   'organizations_url': 'https://api.github.com/users/virajjasani/orgs',
#   'received_events_url': 'https://api.github.com/users/virajjasani/received_events',
#   'repos_url': 'https://api.github.com/users/virajjasani/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/virajjasani/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/virajjasani/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/virajjasani'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/3181402?v=4',
#   'contributions': 140,
#   'events_url': 'https://api.github.com/users/xgong/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/xgong/followers',
#   'following_url': 'https://api.github.com/users/xgong/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/xgong/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/xgong',
#   'id': 3181402,
#   'login': 'xgong',
#   'node_id': 'MDQ6VXNlcjMxODE0MDI=',
#   'organizations_url': 'https://api.github.com/users/xgong/orgs',
#   'received_events_url': 'https://api.github.com/users/xgong/received_events',
# ...
#   'gists_url': 'https://api.github.com/users/virajith/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/virajith',
#   'id': 5614738,
#   'login': 'virajith',
#   'node_id': 'MDQ6VXNlcjU2MTQ3Mzg=',
#   'organizations_url': 'https://api.github.com/users/virajith/orgs',
#   'received_events_url': 'https://api.github.com/users/virajith/received_events',
#   'repos_url': 'https://api.github.com/users/virajith/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/virajith/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/virajith/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/virajith'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/8215991?v=4',
#   'contributions': 43,
#   'events_url': 'https://api.github.com/users/rakeshadr/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/rakeshadr/followers',
#   'following_url': 'https://api.github.com/users/rakeshadr/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/rakeshadr/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/rakeshadr',
#   'id': 8215991,
#   'login': 'rakeshadr',
#   'node_id': 'MDQ6VXNlcjgyMTU5OTE=',
#   'organizations_url': 'https://api.github.com/users/rakeshadr/orgs',
#   'received_events_url': 'https://api.github.com/users/rakeshadr/received_events',
#   'repos_url': 'https://api.github.com/users/rakeshadr/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/rakeshadr/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/rakeshadr/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/rakeshadr'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/6416939?v=4',
#   'contributions': 42,
#   'events_url': 'https://api.github.com/users/jianghuazhu/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/jianghuazhu/followers',
#   'following_url': 'https://api.github.com/users/jianghuazhu/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/jianghuazhu/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/jianghuazhu',
#   'id': 6416939,
#   'login': 'jianghuazhu',
#   'node_id': 'MDQ6VXNlcjY0MTY5Mzk=',
#   'organizations_url': 'https://api.github.com/users/jianghuazhu/orgs',
#   'received_events_url': 'https://api.github.com/users/jianghuazhu/received_events',
#   'repos_url': 'https://api.github.com/users/jianghuazhu/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/jianghuazhu/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/jianghuazhu/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/jianghuazhu'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/10720944?v=4',
#   'contributions': 42,
#   'events_url': 'https://api.github.com/users/mukund-thakur/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/mukund-thakur/followers',
#   'following_url': 'https://api.github.com/users/mukund-thakur/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/mukund-thakur/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/mukund-thakur',
#   'id': 10720944,
#   'login': 'mukund-thakur',
#   'node_id': 'MDQ6VXNlcjEwNzIwOTQ0',
#   'organizations_url': 'https://api.github.com/users/mukund-thakur/orgs',
#   'received_events_url': 'https://api.github.com/users/mukund-thakur/received_events',
#   'repos_url': 'https://api.github.com/users/mukund-thakur/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/mukund-thakur/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/mukund-thakur/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/mukund-thakur'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/74205577?v=4',
#   'contributions': 40,
#   'events_url': 'https://api.github.com/users/erichadoop/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/erichadoop/followers',
#   'following_url': 'https://api.github.com/users/erichadoop/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/erichadoop/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/erichadoop',
#   'id': 74205577,
#   'login': 'erichadoop',
#   'node_id': 'MDQ6VXNlcjc0MjA1NTc3',
#   'organizations_url': 'https://api.github.com/users/erichadoop/orgs',
#   'received_events_url': 'https://api.github.com/users/erichadoop/received_events',
#   'repos_url': 'https://api.github.com/users/erichadoop/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/erichadoop/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/erichadoop/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/erichadoop'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/2583464?v=4',
#   'contributions': 39,
#   'events_url': 'https://api.github.com/users/mingmasplace/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/mingmasplace/followers',
#   'following_url': 'https://api.github.com/users/mingmasplace/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/mingmasplace/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/mingmasplace',
#   'id': 2583464,
#   'login': 'mingmasplace',
#   'node_id': 'MDQ6VXNlcjI1ODM0NjQ=',
#   'organizations_url': 'https://api.github.com/users/mingmasplace/orgs',
#   'received_events_url': 'https://api.github.com/users/mingmasplace/received_events',
#   'repos_url': 'https://api.github.com/users/mingmasplace/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/mingmasplace/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/mingmasplace/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/mingmasplace'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/95350?v=4',
#   'contributions': 39,
#   'events_url': 'https://api.github.com/users/jghoman/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/jghoman/followers',
#   'following_url': 'https://api.github.com/users/jghoman/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/jghoman/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/jghoman',
#   'id': 95350,
#   'login': 'jghoman',
#   'node_id': 'MDQ6VXNlcjk1MzUw',
#   'organizations_url': 'https://api.github.com/users/jghoman/orgs',
#   'received_events_url': 'https://api.github.com/users/jghoman/received_events',
#   'repos_url': 'https://api.github.com/users/jghoman/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/jghoman/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/jghoman/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/jghoman'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/2773275?v=4',
#   'contributions': 38,
#   'events_url': 'https://api.github.com/users/hungj/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/hungj/followers',
#   'following_url': 'https://api.github.com/users/hungj/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/hungj/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/hungj',
#   'id': 2773275,
#   'login': 'hungj',
#   'node_id': 'MDQ6VXNlcjI3NzMyNzU=',
#   'organizations_url': 'https://api.github.com/users/hungj/orgs',
#   'received_events_url': 'https://api.github.com/users/hungj/received_events',
#   'repos_url': 'https://api.github.com/users/hungj/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/hungj/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/hungj/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/hungj'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/3187938?v=4',
#   'contributions': 37,
#   'events_url': 'https://api.github.com/users/gerashegalov/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/gerashegalov/followers',
#   'following_url': 'https://api.github.com/users/gerashegalov/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/gerashegalov/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/gerashegalov',
#   'id': 3187938,
#   'login': 'gerashegalov',
#   'node_id': 'MDQ6VXNlcjMxODc5Mzg=',
#   'organizations_url': 'https://api.github.com/users/gerashegalov/orgs',
#   'received_events_url': 'https://api.github.com/users/gerashegalov/received_events',
#   'repos_url': 'https://api.github.com/users/gerashegalov/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/gerashegalov/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/gerashegalov/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/gerashegalov'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/1051198?v=4',
#   'contributions': 37,
#   'events_url': 'https://api.github.com/users/vivekratnavel/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/vivekratnavel/followers',
#   'following_url': 'https://api.github.com/users/vivekratnavel/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/vivekratnavel/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/vivekratnavel',
#   'id': 1051198,
#   'login': 'vivekratnavel',
#   'node_id': 'MDQ6VXNlcjEwNTExOTg=',
#   'organizations_url': 'https://api.github.com/users/vivekratnavel/orgs',
#   'received_events_url': 'https://api.github.com/users/vivekratnavel/received_events',
#   'repos_url': 'https://api.github.com/users/vivekratnavel/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/vivekratnavel/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/vivekratnavel/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/vivekratnavel'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/25390047?v=4',
#   'contributions': 36,
#   'events_url': 'https://api.github.com/users/mehakmeet/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/mehakmeet/followers',
#   'following_url': 'https://api.github.com/users/mehakmeet/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/mehakmeet/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/mehakmeet',
#   'id': 25390047,
#   'login': 'mehakmeet',
#   'node_id': 'MDQ6VXNlcjI1MzkwMDQ3',
#   'organizations_url': 'https://api.github.com/users/mehakmeet/orgs',
#   'received_events_url': 'https://api.github.com/users/mehakmeet/received_events',
#   'repos_url': 'https://api.github.com/users/mehakmeet/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/mehakmeet/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/mehakmeet/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/mehakmeet'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/24417674?v=4',
#   'contributions': 35,
#   'events_url': 'https://api.github.com/users/9uapaw/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/9uapaw/followers',
#   'following_url': 'https://api.github.com/users/9uapaw/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/9uapaw/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/9uapaw',
#   'id': 24417674,
#   'login': '9uapaw',
#   'node_id': 'MDQ6VXNlcjI0NDE3Njc0',
#   'organizations_url': 'https://api.github.com/users/9uapaw/orgs',
#   'received_events_url': 'https://api.github.com/users/9uapaw/received_events',
#   'repos_url': 'https://api.github.com/users/9uapaw/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/9uapaw/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/9uapaw/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/9uapaw'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/959768?v=4',
#   'contributions': 34,
#   'events_url': 'https://api.github.com/users/sborya/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/sborya/followers',
#   'following_url': 'https://api.github.com/users/sborya/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/sborya/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/sborya',
#   'id': 959768,
#   'login': 'sborya',
#   'node_id': 'MDQ6VXNlcjk1OTc2OA==',
#   'organizations_url': 'https://api.github.com/users/sborya/orgs',
#   'received_events_url': 'https://api.github.com/users/sborya/received_events',
#   'repos_url': 'https://api.github.com/users/sborya/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/sborya/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/sborya/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/sborya'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/3080594?v=4',
#   'contributions': 34,
#   'events_url': 'https://api.github.com/users/abmodi/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/abmodi/followers',
#   'following_url': 'https://api.github.com/users/abmodi/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/abmodi/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/abmodi',
#   'id': 3080594,
#   'login': 'abmodi',
#   'node_id': 'MDQ6VXNlcjMwODA1OTQ=',
#   'organizations_url': 'https://api.github.com/users/abmodi/orgs',
#   'received_events_url': 'https://api.github.com/users/abmodi/received_events',
#   'repos_url': 'https://api.github.com/users/abmodi/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/abmodi/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/abmodi/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/abmodi'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/1883812?v=4',
#   'contributions': 33,
#   'events_url': 'https://api.github.com/users/jzhuge/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/jzhuge/followers',
#   'following_url': 'https://api.github.com/users/jzhuge/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/jzhuge/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/jzhuge',
#   'id': 1883812,
#   'login': 'jzhuge',
#   'node_id': 'MDQ6VXNlcjE4ODM4MTI=',
#   'organizations_url': 'https://api.github.com/users/jzhuge/orgs',
#   'received_events_url': 'https://api.github.com/users/jzhuge/received_events',
#   'repos_url': 'https://api.github.com/users/jzhuge/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/jzhuge/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/jzhuge/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/jzhuge'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/6579005?v=4',
#   'contributions': 32,
#   'events_url': 'https://api.github.com/users/raviprak-altiscale/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/raviprak-altiscale/followers',
#   'following_url': 'https://api.github.com/users/raviprak-altiscale/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/raviprak-altiscale/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/raviprak-altiscale',
#   'id': 6579005,
#   'login': 'raviprak-altiscale',
#   'node_id': 'MDQ6VXNlcjY1NzkwMDU=',
#   'organizations_url': 'https://api.github.com/users/raviprak-altiscale/orgs',
#   'received_events_url': 'https://api.github.com/users/raviprak-altiscale/received_events',
#   'repos_url': 'https://api.github.com/users/raviprak-altiscale/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/raviprak-altiscale/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/raviprak-altiscale/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/raviprak-altiscale'}]

# %% [markdown]
# 3. For each of the 100 contributors extracted in (2), write code that accesses their user information and extracts "login", "id", "location", "email", "hireable", "bio", "twitter_username", "public_repos", "public_gists", "followers", "following", "created_at" (and print those to screen)

# %%
for contributor in contributors_json:
    user_url = contributor['url']
    user_response = requests.get(user_url, headers = headers)
    user_json = user_response.json()

    login = user_json['login']
    user_id = user_json['id']
    location = user_json['location']
    email = user_json['email']
    hireable = user_json['hireable']
    bio = user_json['bio']
    twitter_username = user_json['twitter_username']
    public_repos = user_json['public_repos']
    public_gists = user_json['public_gists']
    followers = user_json['followers']
    following = user_json['following']
    created_at = user_json['created_at']

    print(f"Login: {login}")
    print(f"ID: {user_id}")
    print(f"Location: {location}")
    print(f"Email: {email}")
    print(f"Hireable: {hireable}")
    print(f"Bio: {bio}")
    print(f"Twitter Username: {twitter_username}")
    print(f"Public Repos: {public_repos}")
    print(f"Public Gists: {public_gists}")
    print(f"Followers: {followers}")
    print(f"Following: {following}")
    print(f"Created At: {created_at}")
    print()
# Out:
# Login: aajisaka
# ID: 3403122
# Location: Tokyo, Japan
# Email: None
# Hireable: None
# Bio: Software engineer @aws Glue. Apache (@apache) Hadoop/Yetus/Incubator committer and PMC member. Apache Member. I like OSS and distributed systems.
# Twitter Username: ajis_ka
# Public Repos: 31
# Public Gists: 43
# Followers: 210
# Following: 47
# Created At: 2013-01-28T07:02:40Z
#
# Login: vinoduec
# ID: 384796
# Location: None
# Email: None
# Hireable: None
# Bio: None
# Twitter Username: None
# Public Repos: 1
# Public Gists: 1
# Followers: 37
# Following: 0
# Created At: 2010-09-02T07:32:46Z
#
# Login: szetszwo
# ID: 907380
# Location: None
# Email: None
# Hireable: None
# Bio: None
# Twitter Username: None
# Public Repos: 6
# Public Gists: 0
# Followers: 65
# Following: 0
# Created At: 2011-07-11T09:30:08Z
#
# Login: arp7
# ID: 2480225
# Location: None
# Email: None
# Hireable: None
# Bio: None
# Twitter Username: None
# Public Repos:
# Hireable: None
# Bio: None
# Twitter Username: None
# Public Repos: 26
# Public Gists: 1
# Followers: 26
# Following: 6
# Created At: 2011-09-14T19:25:16Z
#
# Login: mehakmeet
# ID: 25390047
# Location: None
# Email: None
# Hireable: None
# Bio: Cloud Connectors and Algorithms.
# Twitter Username: None
# Public Repos: 32
# Public Gists: 0
# Followers: 11
# Following: 7
# Created At: 2017-01-27T16:36:12Z
#
# Login: 9uapaw
# ID: 24417674
# Location: None
# Email: None
# Hireable: None
# Bio: None
# Twitter Username: None
# Public Repos: 15
# Public Gists: 0
# Followers: 6
# Following: 7
# Created At: 2016-12-06T18:38:41Z
#
# Login: sborya
# ID: 959768
# Location: None
# Email: None
# Hireable: None
# Bio: None
# Twitter Username: None
# Public Repos: 4
# Public Gists: 0
# Followers: 1
# Following: 0
# Created At: 2011-08-04T19:27:33Z
#
# Login: abmodi
# ID: 3080594
# Location: Bangalore
# Email: abmodi@apache.org
# Hireable: None
# Bio: Learning big-data.
# Twitter Username: None
# Public Repos: 25
# Public Gists: 0
# Followers: 7
# Following: 3
# Created At: 2012-12-19T12:16:02Z
#
# Login: jzhuge
# ID: 1883812
# Location: San Francisco Bay Area
# Email: jzhuge@apache.org
# Hireable: None
# Bio: Apache Hadoop PMC. Interested in hyper-scale storage systems, distributed systems, cloud computing, concurrent, reactive, and parallel programming.
# Twitter Username: None
# Public Repos: 37
# Public Gists: 3
# Followers: 48
# Following: 6
# Created At: 2012-06-23T08:52:44Z
#
# Login: raviprak-altiscale
# ID: 6579005
# Location: Palo Alto, CA
# Email: None
# Hireable: None
# Bio: None
# Twitter Username: None
# Public Repos: 0
# Public Gists: 1
# Followers: 4
# Following: 0
# Created At: 2014-02-03T21:27:28Z

# %% [markdown]
# 4. Write code that creates an SQL database + table, and stores all the information obtained in (3) in it.  Please be cautious of the data type you choose for each collumn and briefly justify your decisions.  What do you choose as Primary Key and why?

# %% [markdown]
# **Answer :** <br>
# I choose user_id as primary key as this is the field that each user has unique value; I set those columns with numbers and strings to be of type "VARCHAR" and those columns with only numbers to be of type "INT".

# %%
## Create a new database to create table into

# Connect to MySQL server
conn = mysql.connector.connect(host='localhost',user='root',password='wyz710522')
# Create a cursor to execute SQL queries
cursor = conn.cursor()
# Create a new database if not exist
SQL_DB = "github"
query_Database = "CREATE DATABASE IF NOT EXISTS " + SQL_DB
cursor.execute(query_Database)

# %%
## Create Table in the database 

# Connect to MySQL server
conn = mysql.connector.connect(host='localhost',user='root',password='wyz710522')
# Create a cursor to execute SQL queries
cursor = conn.cursor()
# Create a new table if not exist to include all the columns needed
SQL_TABLE_CONTRIBUTORS = "Contributors"
SQL_TABLE_CONTRIBUTORS_DEF = "(" + \
        "login VARCHAR(300) NOT NULL," + \
        "user_id INT NOT NULL AUTO_INCREMENT PRIMARY KEY," + \
        "location VARCHAR(300)," + \
        "email VARCHAR(300)," + \
        "hireable INT," + \
        "bio VARCHAR(300)," + \
        "twitter_username VARCHAR(300)," + \
        "public_repos INT," + \
        "public_gists INT," + \
        "followers INT," + \
        "following INT," + \
        "created_at VARCHAR(300)" + \
        ")"
query_Table = "CREATE TABLE IF NOT EXISTS " + SQL_DB + "." + SQL_TABLE_CONTRIBUTORS + " " + SQL_TABLE_CONTRIBUTORS_DEF + ";";
cursor.execute(query_Table)

# %%
## Fetch all the content of the table
headers = {'Authorization' : 'token ' + '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'}
url = 'https://api.github.com/repos/apache/hadoop/contributors'
response = requests.get(url,headers = headers, params={'per_page': 100})
contributors_json = response.json()
        
logins = []
user_ids = []
locations = []
emails = []
hireables = []
bios = []
twitter_usernames = []
public_reposs = []
public_gistss  = []
followerss = []
followings = []
created_ats = []
        
for contributor in contributors_json:
    user_url = contributor['url']
    user_response = requests.get(user_url, headers = headers)
    user_json = user_response.json()
    login = user_json['login']
    logins.append(login)
    user_id = user_json['id']
    user_ids.append(user_id)
    location = user_json['location']
    locations.append(location)
    email = user_json['email']
    emails.append(email)
    hireable = user_json['hireable']
    hireables.append(hireable)
    bio = user_json['bio']
    bios.append(bio)
    twitter_username = user_json['twitter_username']
    twitter_usernames.append(twitter_username)
    public_repos = user_json['public_repos']
    public_reposs.append(public_repos)
    public_gists = user_json['public_gists']
    public_gistss.append(public_gists)
    followers = user_json['followers']
    followerss.append(followers)
    following = user_json['following']
    followings.append(following)
    created_at = user_json['created_at']
    created_ats.append(created_at)

# %%
## Insert all the values into the table created 

# Connect to MySQL server
conn = mysql.connector.connect(host='localhost',user='root',database = "github",password='wyz710522')
# Create a cursor to execute SQL queries
cursor = conn.cursor()
# Insert the fetched values into the table 
query_Insert = f"INSERT INTO {SQL_TABLE_CONTRIBUTORS} (login, user_id, location, email, hireable, bio, twitter_username, public_repos, public_gists, followers, following, created_at) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s);"
values = []
for i in range(len(logins)) :
    row = (logins[i], user_ids[i], locations[i], emails[i], hireables[i], bios[i], twitter_usernames[i], 
           public_reposs[i], public_gistss[i], followerss[i], followings[i], created_ats[i])
    values.append(row)
cursor.executemany(query_Insert, values)

# Commit changes to the database
conn.commit()
# Close connection
conn.close()

# %% [markdown]
# 5. Optimize your code in (4) to allow for quick look-ups of "login", "location", and "hireable".  What choices do you make and why?

# %% [markdown]
# **Optmized code by indexing the three columns**

# %%
## Create another Table using the method of Indexd columns in the database 

# Connect to MySQL server
conn = mysql.connector.connect(host='localhost',user='root',database = 'github',password='wyz710522')
# Create a cursor to execute SQL queries
cursor = conn.cursor()
# Create a new table if not exist to include all the columns needed
SQL_TABLE_CONTRIBUTORS_NEW = "Contributors_New"
SQL_TABLE_CONTRIBUTORS_NEW_DEF = "(" + \
        "login VARCHAR(300)," + \
        "user_id INT NOT NULL AUTO_INCREMENT PRIMARY KEY," + \
        "location VARCHAR(300)," + \
        "email VARCHAR(300)," + \
        "hireable INT," + \
        "bio VARCHAR(300)," + \
        "twitter_username VARCHAR(300)," + \
        "public_repos INT," + \
        "public_gists INT," + \
        "followers INT," + \
        "following INT," + \
        "INDEX (login)," + \
        "INDEX (location)," + \
        "INDEX (hireable)," + \
        "created_at VARCHAR(300)" + \
        ")"
query_Table = "CREATE TABLE IF NOT EXISTS " + SQL_DB + "." + SQL_TABLE_CONTRIBUTORS_NEW + " " + SQL_TABLE_CONTRIBUTORS_NEW_DEF + ";";
cursor.execute(query_Table)

# %%
## Fetch all the content of the table
headers = {'Authorization' : 'token ' + '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'}
url = 'https://api.github.com/repos/apache/hadoop/contributors'
response = requests.get(url,headers = headers, params={'per_page': 100})
contributors_json = response.json()
        
logins = []
user_ids = []
locations = []
emails = []
hireables = []
bios = []
twitter_usernames = []
public_reposs = []
public_gistss  = []
followerss = []
followings = []
created_ats = []
        
for contributor in contributors_json:
    user_url = contributor['url']
    user_response = requests.get(user_url, headers = headers)
    user_json = user_response.json()
    login = user_json['login']
    logins.append(login)
    user_id = user_json['id']
    user_ids.append(user_id)
    location = user_json['location']
    locations.append(location)
    email = user_json['email']
    emails.append(email)
    hireable = user_json['hireable']
    hireables.append(hireable)
    bio = user_json['bio']
    bios.append(bio)
    twitter_username = user_json['twitter_username']
    twitter_usernames.append(twitter_username)
    public_repos = user_json['public_repos']
    public_reposs.append(public_repos)
    public_gists = user_json['public_gists']
    public_gistss.append(public_gists)
    followers = user_json['followers']
    followerss.append(followers)
    following = user_json['following']
    followings.append(following)
    created_at = user_json['created_at']
    created_ats.append(created_at)

# %%
## Insert all the values into the table created 

# Connect to MySQL server
conn = mysql.connector.connect(host='localhost',user='root',database = "github",password='wyz710522')
# Create a cursor to execute SQL queries
cursor = conn.cursor()
# Insert the fetched values into the table 
query_Insert = f"INSERT INTO {SQL_TABLE_CONTRIBUTORS_NEW} (login, user_id, location, email, hireable, bio, twitter_username, public_repos, public_gists, followers, following, created_at) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s);"
values = []
for i in range(len(logins)) :
    row = (logins[i], user_ids[i], locations[i], emails[i], hireables[i], bios[i], twitter_usernames[i], 
           public_reposs[i], public_gistss[i], followerss[i], followings[i], created_ats[i])
    values.append(row)
cursor.executemany(query_Insert, values)

# Commit changes to the database
conn.commit()
# Close connection
conn.close()

# %% [markdown]
# **Check the difference of speed of running**

# %%
# Previous Method
conn = mysql.connector.connect(host='localhost',user='root',database = "github",password='wyz710522')
start = time.time()
cursor = conn.cursor()
cursor.execute("SELECT login , user_id , location FROM Contributors WHERE location in ('San Francisco','Tokyo','Seattle')")
result = cursor.fetchall()
end = time.time()
# The time of executing 
execution_time = end - start
print("Previous Method's Execution Time is {}".format(execution_time))
# Out:
# Previous Method's Execution Time is 0.005464076995849609

# %%
# After we indexed the columns
conn = mysql.connector.connect(host='localhost',user='root',database = "github",password='wyz710522')
start_new = time.time()
cursor = conn.cursor()
cursor.execute("SELECT login , user_id , location FROM Contributors_New WHERE location in ('San Francisco','Tokyo','Seattle')")
result = cursor.fetchall()
end_new = time.time()
# The time of executing 
execution_time_new = end_new - start_new
print("Current Method's Execution Time is {}".format(execution_time_new))
# Out:
# Current Method's Execution Time is 0.0019741058349609375

# %%
# % Increase of Speed
per_speed_increase = round(((execution_time - execution_time_new) / execution_time)*100,2)
print("The speed has been increased by {}% after we indexed the columns".format(per_speed_increase))
# Out:
# The speed has been increased by 63.87% after we indexed the columns
